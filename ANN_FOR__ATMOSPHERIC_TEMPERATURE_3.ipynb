# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_excel('/content/density16.xlsx')

# %%
df
# Out:
#         x1  d (g cm-3) VE (cm3 mol-1)
# 0   0.0120     0.76802         −0.073
# 1   0.0310     0.77631         −0.184
# 2   0.0500     0.78419         −0.278
# 3   0.1000     0.80401         −0.502
# 4   0.1500     0.82217         −0.674
# 5   0.2002     0.83911         −0.811
# 6   0.2501     0.85448         −0.901
# 7   0.2974     0.86811         −0.967
# 8   0.3502     0.88225         −1.011
# 9   0.4001     0.89433         −1.013
# 10  0.4427     0.90414         −1.006
# 11  0.4502     0.90597         −1.012
# 12  0.5002     0.91646         −0.976
# 13  0.5501     0.92630         −0.927
# 14  0.6001     0.93562         −0.868
# 15  0.6501     0.94431         −0.795
# 16  0.7005     0.95272         −0.719
# 17  0.7479     0.95978         −0.616
# 18  0.8002     0.96771         −0.527
# 19  0.8502     0.97423         −0.396
# 20  0.8967     0.98048         −0.299
# 21  0.9501     0.98681         −0.152

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt



# Assuming df is already defined and contains the necessary data
# Adding constant temperature T as a feature
# Adding constant temperature T as a feature
df['T'] = 323.15


# Rename columns to remove special characters and spaces
df['VE_(cm3_mol-1)'] = df['VE (cm3 mol-1)'].str.replace('−', '-') # Replace special character if needed.
df['VE_(cm3_mol-1)'] = df['VE_(cm3_mol-1)'].astype(float) # Converting the column to float
df['d_(g_cm-3)'] = df['d (g cm-3)']  # Rename with underscores

# Drop original columns with special characters and spaces
df = df.drop(['VE (cm3 mol-1)', 'd (g cm-3)'], axis=1)

# Verify the column names
print("Columns:", df.columns)

# Input features and target variables
X = df[['x1', 'T']].values
y = df[['d_(g_cm-3)', 'VE_(cm3_mol-1)']].values

# Standardize the data
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Build the ANN model with more layers
model = Sequential()
model.add(Dense(64, input_dim=X_scaled.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))  # Additional hidden layer
model.add(Dense(8, activation='relu'))   # Additional hidden layer
model.add(Dense(2))  # Output layer for two target variables

# Custom RMSE loss function
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# Compile the model with a different optimizer and increased learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=rmse)

# Train the model
history = model.fit(X_scaled, y_scaled, epochs=200, batch_size=64, validation_split=0.2)

# Predict and inverse transform the results
y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_original = scaler_y.inverse_transform(y_scaled)

# Calculate the error percentage (MAPE) for each target variable separately
mape_density = np.mean(np.abs((y_original[:, 0] - y_pred[:, 0]) / y_original[:, 0])) * 100
mape_ve = np.mean(np.abs((y_original[:, 1] - y_pred[:, 1]) / y_original[:, 1])) * 100

print(f"Mean Absolute Percentage Error (MAPE) for Density: {mape_density:.2f}%")
print(f"Mean Absolute Percentage Error (MAPE) for VE: {mape_ve:.2f}%")

# Prepare a comparison DataFrame
comparison = pd.DataFrame({
    'x1': X[:, 0],
    'T': X[:, 1],
    'd_actual': y_original[:, 0],
    'd_predicted': y_pred[:, 0],
    'VE_actual': y_original[:, 1],
    'VE_predicted': y_pred[:, 1],
})

# Display the comparison table
print(comparison.to_string(index=False))

# Save the comparison DataFrame to an Excel file
comparison.to_excel('comparison_results.xlsx', index=False)

print("Comparison results saved to 'comparison_results.xlsx'")

# Plotting the loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train RMSE', color='blue')
plt.plot(history.history['val_loss'], label='Validation RMSE', color='red')
plt.xlabel('Epochs')
plt.ylabel('RMSE')
plt.title('Training and Validation RMSE')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Columns: Index(['x1', 'T', 'VE_(cm3_mol-1)', 'd_(g_cm-3)'], dtype='object')
# Epoch 1/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.9607 - val_loss: 0.9715
# Epoch 2/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.9551 - val_loss: 0.9586
# Epoch 3/200
# 1/1 [==============================] - 0s 94ms/step - loss: 0.9497 - val_loss: 0.9461
# Epoch 4/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.9453 - val_loss: 0.9388
# Epoch 5/200
# 1/1 [==============================] - 0s 106ms/step - loss: 0.9409 - val_loss: 0.9319
# Epoch 6/200
# 1/1 [==============================] - 0s 98ms/step - loss: 0.9364 - val_loss: 0.9262
# Epoch 7/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.9319 - val_loss: 0.9223
# Epoch 8/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.9271 - val_loss: 0.9193
# Epoch 9/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.9238 - val_loss: 0.9169
# Epoch 10/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.9203 - val_loss: 0.9151
# Epoch 11/200
# 1/1 [==============================] - 0s 161ms/step - loss: 0.9166 - val_loss: 0.9136
# Epoch 12/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.9126 - val_loss: 0.9125
# Epoch 13/200
# 1/1 [==============================] - 0s 162ms/step - loss: 0.9083 - val_loss: 0.9115
# Epoch 14/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.9037 - val_loss: 0.9106
# Epoch 15/200
# 1/1 [==============================] - 0s 99ms/step - loss: 0.8989 - val_loss: 0.9101
# Epoch 16/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.8940 - val_loss: 0.9103
# Epoch 17/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.8888 - val_loss: 0.9110
# Epoch 18/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.8835 - val_loss: 0.9127
# Epoch 19/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.8785 - val_loss: 0.9158
# Epoch 20/200
# 1/1 [==============================] - 0s 88ms/step - loss: 0.8735 - val_loss: 0.9203
# Epoch 21/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.8683 - val_loss: 0.9264
# Epoch 22/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.8628 - val_loss: 0.9338
# Epoch 23/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.8571 - val_loss: 0.9430
# Epoch 24/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.8512 - val_loss: 0.9549
# Epoch 25/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.8452 - val_loss: 0.9683
# Epoch 26/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.8395 - val_loss: 0.9829
# Epoch 27/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.8334 - val_loss: 0.9981
# Epoch 28/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.8270 - val_loss: 1.0138
# Epoch 29/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.8212 - val_loss: 1.0302
# Epoch 30/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.8148 - val_loss: 1.0472
# Epoch 31/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.8085 - val_loss: 1.0647
# Epoch 32/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.8019 - val_loss: 1.0831
# Epoch 33/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7953 - val_loss: 1.1022
# Epoch 34/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7887 - val_loss: 1.1217
# Epoch 35/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.7820 - val_loss: 1.1413
# Epoch 36/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7751 - val_loss: 1.1612
# Epoch 37/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.7681 - val_loss: 1.1810
# Epoch 38/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7610 - val_loss: 1.2003
# Epoch 39/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.7538 - val_loss: 1.2192
# Epoch 40/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.7468 - val_loss: 1.2376
# Epoch 41/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7397 - val_loss: 1.2551
# Epoch 42/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.7325 - val_loss: 1.2710
# Epoch 43/200
# 1/1 [==============================] - 0s 97ms/step - loss: 0.7253 - val_loss: 1.2848
# Epoch 44/200
# 1/1 [==============================] - 0s 190ms/step - loss: 0.7182 - val_loss: 1.2963
# Epoch 45/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.7110 - val_loss: 1.3056
# Epoch 46/200
# 1/1 [==============================] - 0s 152ms/step - loss: 0.7035 - val_loss: 1.3122
# Epoch 47/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.6958 - val_loss: 1.3164
# Epoch 48/200
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6878 - val_loss: 1.3191
# Epoch 49/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6795 - val_loss: 1.3200
# Epoch 50/200
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6712 - val_loss: 1.3188
# Epoch 51/200
# 1/1 [==============================] - 0s 82ms/step - loss: 0.6636 - val_loss: 1.3154
# Epoch 52/200
# 1/1 [==============================] - 0s 79ms/step - loss: 0.6557 - val_loss: 1.3101
# Epoch 53/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6475 - val_loss: 1.3030
# Epoch 54/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6390 - val_loss: 1.2947
# Epoch 55/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6303 - val_loss: 1.2840
# Epoch 56/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6213 - val_loss: 1.2718
# Epoch 57/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6121 - val_loss: 1.2584
# Epoch 58/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6026 - val_loss: 1.2435
# Epoch 59/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5928 - val_loss: 1.2272
# Epoch 60/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5827 - val_loss: 1.2094
# Epoch 61/200
# 1/1 [==============================] - 0s 143ms/step - loss: 0.5723 - val_loss: 1.1901
# Epoch 62/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.5618 - val_loss: 1.1692
# Epoch 63/200
# 1/1 [==============================] - 0s 167ms/step - loss: 0.5507 - val_loss: 1.1470
# Epoch 64/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5394 - val_loss: 1.1238
# Epoch 65/200
# 1/1 [==============================] - 0s 82ms/step - loss: 0.5277 - val_loss: 1.0998
# Epoch 66/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5156 - val_loss: 1.0751
# Epoch 67/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5031 - val_loss: 1.0490
# Epoch 68/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4904 - val_loss: 1.0212
# Epoch 69/200
# 1/1 [==============================] - 0s 87ms/step - loss: 0.4777 - val_loss: 0.9924
# Epoch 70/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4645 - val_loss: 0.9630
# Epoch 71/200
# 1/1 [==============================] - 0s 151ms/step - loss: 0.4512 - val_loss: 0.9329
# Epoch 72/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4376 - val_loss: 0.9025
# Epoch 73/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4239 - val_loss: 0.8718
# Epoch 74/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4099 - val_loss: 0.8417
# Epoch 75/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3955 - val_loss: 0.8123
# Epoch 76/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3806 - val_loss: 0.7836
# Epoch 77/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3653 - val_loss: 0.7551
# Epoch 78/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3493 - val_loss: 0.7265
# Epoch 79/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.3330 - val_loss: 0.6982
# Epoch 80/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3162 - val_loss: 0.6691
# Epoch 81/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2992 - val_loss: 0.6381
# Epoch 82/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2816 - val_loss: 0.6053
# Epoch 83/200
# 1/1 [==============================] - 0s 107ms/step - loss: 0.2635 - val_loss: 0.5718
# Epoch 84/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.2451 - val_loss: 0.5386
# Epoch 85/200
# 1/1 [==============================] - 0s 101ms/step - loss: 0.2263 - val_loss: 0.5080
# Epoch 86/200
# 1/1 [==============================] - 0s 97ms/step - loss: 0.2072 - val_loss: 0.4824
# Epoch 87/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.1882 - val_loss: 0.4614
# Epoch 88/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.1696 - val_loss: 0.4448
# Epoch 89/200
# 1/1 [==============================] - 0s 155ms/step - loss: 0.1517 - val_loss: 0.4336
# Epoch 90/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1346 - val_loss: 0.4264
# Epoch 91/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1194 - val_loss: 0.4188
# Epoch 92/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.1065 - val_loss: 0.4162
# Epoch 93/200
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0965 - val_loss: 0.4165
# Epoch 94/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0911 - val_loss: 0.4198
# Epoch 95/200
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0889 - val_loss: 0.4280
# Epoch 96/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0882 - val_loss: 0.4384
# Epoch 97/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0872 - val_loss: 0.4497
# Epoch 98/200
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0845 - val_loss: 0.4629
# Epoch 99/200
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0793 - val_loss: 0.4779
# Epoch 100/200
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0720 - val_loss: 0.4916
# Epoch 101/200
# 1/1 [==============================] - 0s 156ms/step - loss: 0.0635 - val_loss: 0.5053
# Epoch 102/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0558 - val_loss: 0.5145
# Epoch 103/200
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0502 - val_loss: 0.5196
# Epoch 104/200
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0475 - val_loss: 0.5214
# Epoch 105/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0466 - val_loss: 0.5238
# Epoch 106/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0462 - val_loss: 0.5243
# Epoch 107/200
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0460 - val_loss: 0.5223
# Epoch 108/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0464 - val_loss: 0.5108
# Epoch 109/200
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0493 - val_loss: 0.5154
# Epoch 110/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0471 - val_loss: 0.5050
# Epoch 111/200
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0386 - val_loss: 0.4973
# Epoch 112/200
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0398 - val_loss: 0.5006
# Epoch 113/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0386 - val_loss: 0.4856
# Epoch 114/200
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0312 - val_loss: 0.4744
# Epoch 115/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0338 - val_loss: 0.4797
# Epoch 116/200
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0333 - val_loss: 0.4691
# Epoch 117/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0272 - val_loss: 0.4594
# Epoch 118/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0291 - val_loss: 0.4650
# Epoch 119/200
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0284 - val_loss: 0.4543
# Epoch 120/200
# 1/1 [==============================] - 0s 206ms/step - loss: 0.0226 - val_loss: 0.4514
# Epoch 121/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0241 - val_loss: 0.4607
# Epoch 122/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0270 - val_loss: 0.4519
# Epoch 123/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0228 - val_loss: 0.4527
# Epoch 124/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0230 - val_loss: 0.4651
# Epoch 125/200
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0253 - val_loss: 0.4605
# Epoch 126/200
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0222 - val_loss: 0.4640
# Epoch 127/200
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0208 - val_loss: 0.4673
# Epoch 128/200
# 1/1 [==============================] - 0s 175ms/step - loss: 0.0222 - val_loss: 0.4605
# Epoch 129/200
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0216 - val_loss: 0.4695
# Epoch 130/200
# 1/1 [==============================] - 0s 156ms/step - loss: 0.0197 - val_loss: 0.4713
# Epoch 131/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0200 - val_loss: 0.4624
# Epoch 132/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0208 - val_loss: 0.4687
# Epoch 133/200
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0198 - val_loss: 0.4677
# Epoch 134/200
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0185 - val_loss: 0.4651
# Epoch 135/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0186 - val_loss: 0.4663
# Epoch 136/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0192 - val_loss: 0.4561
# Epoch 137/200
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0186 - val_loss: 0.4612
# Epoch 138/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0173 - val_loss: 0.4555
# Epoch 139/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0164 - val_loss: 0.4492
# Epoch 140/200
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0161 - val_loss: 0.4504
# Epoch 141/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0163 - val_loss: 0.4430
# Epoch 142/200
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0171 - val_loss: 0.4466
# Epoch 143/200
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0178 - val_loss: 0.4347
# Epoch 144/200
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0167 - val_loss: 0.4429
# Epoch 145/200
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0152 - val_loss: 0.4372
# Epoch 146/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0143 - val_loss: 0.4391
# Epoch 147/200
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0143 - val_loss: 0.4354
# Epoch 148/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0149 - val_loss: 0.4444
# Epoch 149/200
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0163 - val_loss: 0.4333
# Epoch 150/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0161 - val_loss: 0.4409
# Epoch 151/200
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0142 - val_loss: 0.4357
# Epoch 152/200
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0129 - val_loss: 0.4375
# Epoch 153/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0124 - val_loss: 0.4327
# Epoch 154/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0123 - val_loss: 0.4357
# Epoch 155/200
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0125 - val_loss: 0.4306
# Epoch 156/200
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0133 - val_loss: 0.4383
# Epoch 157/200
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0156 - val_loss: 0.4285
# Epoch 158/200
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0153 - val_loss: 0.4372
# Epoch 159/200
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0127 - val_loss: 0.4313
# Epoch 160/200
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0116 - val_loss: 0.4328
# Epoch 161/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0113 - val_loss: 0.4309
# Epoch 162/200
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0112 - val_loss: 0.4315
# Epoch 163/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0117 - val_loss: 0.4240
# Epoch 164/200
# 1/1 [==============================] - 0s 165ms/step - loss: 0.0137 - val_loss: 0.4352
# Epoch 165/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0156 - val_loss: 0.4236
# Epoch 166/200
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0128 - val_loss: 0.4282
# Epoch 167/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0112 - val_loss: 0.4260
# Epoch 168/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0107 - val_loss: 0.4274
# Epoch 169/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0108 - val_loss: 0.4222
# Epoch 170/200
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0115 - val_loss: 0.4307
# Epoch 171/200
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0139 - val_loss: 0.4191
# Epoch 172/200
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0143 - val_loss: 0.4265
# Epoch 173/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0117 - val_loss: 0.4222
# Epoch 174/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0106 - val_loss: 0.4249
# Epoch 175/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0104 - val_loss: 0.4200
# Epoch 176/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0108 - val_loss: 0.4268
# Epoch 177/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0124 - val_loss: 0.4170
# Epoch 178/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0141 - val_loss: 0.4252
# Epoch 179/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0120 - val_loss: 0.4193
# Epoch 180/200
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0105 - val_loss: 0.4233
# Epoch 181/200
# 1/1 [==============================] - 0s 167ms/step - loss: 0.0102 - val_loss: 0.4184
# Epoch 182/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0105 - val_loss: 0.4245
# Epoch 183/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0119 - val_loss: 0.4159
# Epoch 184/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0133 - val_loss: 0.4240
# Epoch 185/200
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0117 - val_loss: 0.4176
# Epoch 186/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0103 - val_loss: 0.4222
# Epoch 187/200
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0100 - val_loss: 0.4174
# Epoch 188/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0103 - val_loss: 0.4261
# Epoch 189/200
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0117 - val_loss: 0.4131
# Epoch 190/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0128 - val_loss: 0.4235
# Epoch 191/200
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0112 - val_loss: 0.4179
# Epoch 192/200
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0100 - val_loss: 0.4179
# Epoch 193/200
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0098 - val_loss: 0.4164
# Epoch 194/200
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0101 - val_loss: 0.4232
# Epoch 195/200
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0113 - val_loss: 0.4128
# Epoch 196/200
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0122 - val_loss: 0.4209
# Epoch 197/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0110 - val_loss: 0.4180
# Epoch 198/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0099 - val_loss: 0.4197
# Epoch 199/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0096 - val_loss: 0.4151
# Epoch 200/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0100 - val_loss: 0.4233
# 1/1 [==============================] - 0s 101ms/step
# Mean Absolute Percentage Error (MAPE) for Density: 0.05%
# Mean Absolute Percentage Error (MAPE) for VE: 16.42%
#     x1      T  d_actual  d_predicted  VE_actual  VE_predicted
# 0.0120 323.15   0.76802     0.768387     -0.073     -0.088847
# 0.0310 323.15   0.77631     0.776397     -0.184     -0.183660
# 0.0500 323.15   0.78419     0.784406     -0.278     -0.278472
# 0.1000 323.15   0.80401     0.804376     -0.502     -0.500131
# 0.1500 323.15   0.82217     0.822737     -0.674     -0.683289
# 0.2002 323.15   0.83911     0.839412     -0.811     -0.812689
# 0.2501 323.15   0.85448     0.854544     -0.901     -0.902152
# 0.2974 323.15   0.86811     0.867886     -0.967     -0.969385
# 0.3502 323.15   0.88225     0.882335     -1.011     -1.011292
# 0.4001 323.15   0.89433     0.894464     -1.013     -1.013655
# 0.4427 323.15   0.90414     0.904399     -1.006     -1.009846
# 0.4502 323.15   0.90597     0.905772     -1.012     -1.009476
# 0.5002 323.15   0.91646     0.916491     -0.976     -0.977055
# 0.5501 323.15   0.92630     0.926280     -0.927     -0.928254
# 0.6001 323.15   0.93562     0.935604     -0.868     -0.869968
# 0.6501 323.15   0.94431     0.944340     -0.795     -0.796712
# 0.7005 323.15   0.95272     0.952594     -0.719     -0.721430
# 0.7479 323.15   0.95978     0.959902     -0.616     -0.659937
# 0.8002 323.15   0.96771     0.967565     -0.527     -0.602065
# 0.8502 323.15   0.97423     0.975113     -0.396     -0.553845
# 0.8967 323.15   0.98048     0.982131     -0.299     -0.510181
# 0.9501 323.15   0.98681     0.990294     -0.152     -0.460838
# Comparison results saved to 'comparison_results.xlsx'

# %% [markdown]
# import numpy as np
# import pandas as pd
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
# from sklearn.preprocessing import StandardScaler
# import matplotlib.pyplot as plt
#
#
# # Adding constant temperature T as a feature
# df['T'] = 283.15
#
#
# # Input features and target variables
# X = df[['x1', 'T']].values
# y = df[['d_(g_cm-3)', 'VE_(cm3_mol-1)']].values
#
# # Standardize the data
# scaler_X = StandardScaler()
# scaler_y = StandardScaler()
#
# X_scaled = scaler_X.fit_transform(X)
# y_scaled = scaler_y.fit_transform(y)
#
# # Build the ANN model with more layers
# model = Sequential()
# model.add(Dense(64, input_dim=X_scaled.shape[1], activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(16, activation='relu'))  # Additional hidden layer
# model.add(Dense(8, activation='relu'))   # Additional hidden layer
# model.add(Dense(2))  # Output layer for two target variables
#
# # Custom RMSE loss function
# def rmse(y_true, y_pred):
#     return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))
#
# # Compile the model with a different optimizer and increased learning rate
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=rmse)
#
# # Train the model
# history = model.fit(X_scaled, y_scaled, epochs=500, batch_size=16, validation_split=0.2)
#
# # Predict and inverse transform the results
# y_pred_scaled = model.predict(X_scaled)
# y_pred = scaler_y.inverse_transform(y_pred_scaled)
# y_original = scaler_y.inverse_transform(y_scaled)
#
# # Calculate the error percentage (MAPE) for each target variable separately
# mape_density = np.mean(np.abs((y_original[:, 0] - y_pred[:, 0]) / y_original[:, 0])) * 100
# mape_ve = np.mean(np.abs((y_original[:, 1] - y_pred[:, 1]) / y_original[:, 1])) * 100
#
# print(f"Mean Absolute Percentage Error (MAPE) for Density: {mape_density:.2f}%")
# print(f"Mean Absolute Percentage Error (MAPE) for VE: {mape_ve:.2f}%")
#
# # Prepare a comparison DataFrame
# comparison = pd.DataFrame({
#     'x1': X[:, 0],
#     'T': X[:, 1],
#     'd_actual': y_original[:, 0],
#     'd_predicted': y_pred[:, 0],
#     'VE_actual': y_original[:, 1],
#     'VE_predicted': y_pred[:, 1],
# })
#
# # Save the comparison DataFrame to an Excel file
# comparison.to_excel('comparison_results.xlsx', index=False)
#
# print("Comparison results saved to 'comparison_results.xlsx'")
#
# # Plotting the loss
# plt.figure(figsize=(10, 6))
# plt.plot(history.history['loss'], label='Train RMSE', color='blue')
# plt.plot(history.history['val_loss'], label='Validation RMSE', color='red')
# plt.xlabel('Epochs')
# plt.ylabel('RMSE')
# plt.title('Training and Validation RMSE')
# plt.legend()
# plt.grid(True)
# plt.show()
